# %% [markdown]
# # 02 – Análisis de brechas
#
# Identificación y cuantificación de brechas entre el PIB generado por Zonas Francas y el resto de la economía costarricense.

# %%
import sys
sys.path.append('../src')

import pandas as pd
import matplotlib.pyplot as plt
from utils import cargar_datos, guardar_procesado

# %% [markdown]
# ## 1. Carga de datos procesados

# %%
# df = pd.read_csv('../data/processed/datos_limpios.csv')

# %% [markdown]
# ## 2. Cálculo de brechas

# %%
# Calcular participación de Zonas Francas en el PIB total
# brecha = df['pib_total'] - df['pib_zonas_francas']

# %% [markdown]
# ## 3. Evolución temporal

# %%
# Análisis de tendencia y variación anual
